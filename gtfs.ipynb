# %%
import geoplotlib as gpl
import numpy as np
import pandas as pd
import re
import datetime as dt

# %matplotlib inline

# %%
def time_of_day_from_unix_ts(ts):
  """unix timestamp to time of day"""
  return dt.datetime.fromtimestamp(ts).time()

def time_of_day_from_minutes(mins):
  """minutes after midnight to standard time of day"""
  return (dt.datetime(1,1,1) + dt.timedelta(minutes = mins)).time()

def day_of_week_from_datestamp(datestamp):
  """Datestamps like '20180902' -> 6 (for Sunday)"""
  if not(len(datestamp) == 8 and datestamp.isdigit()):
    raise ValueError(f"invalid datestamp: {datestamp}")
  year = int(datestamp[:4])
  month = int(datestamp[4:6])
  day = int(datestamp[6:])
  return dt.date(year, month, day).weekday()

day1 = dt.date(1,1,1)
day2 = dt.date(1,1,2)

def timediff(time1, time2):
  """finds the minimum time between two time-of-day-stamps"""
  if time1 > time2:
    time1, time2 = time2, time1
  diff1 = dt.datetime.combine(day1, time2) - dt.datetime.combine(day1, time1)
  diff2 = dt.datetime.combine(day2, time1) - dt.datetime.combine(day1, time2)
  return min(diff1, diff2)

# %% [markdown]
# Instructions for using this notebook:
# 1. Create a folder to put data in.  Set `datapath` below to that folder's path
# 2. Download the GTFS schedule data (link below), unzip to a folder called `<datapath>/gtfs_schedule`
# 3. Download the GTFS-RT archive data (link in relevant section) and unzip into a folder called `<datapath>/gtfs_realtime/august_2018`.
# 4. Unzip `<datapath>/gtfs_realtime/august_2018/20180801.zip` where it is

# %%
datapath = '/home/tanner/Documents/transit/'

# %% [markdown]
# # GTFS schedule data
# All this is static, i.e. a new version is published on the order of every few months.  It can be downloaded straight from the MTA [here](http://web.mta.info/developers/data/nyct/subway/google_transit.zip).
#
# It consists of a dozen or so tables, all with a standard structure.  Together, these tables define everything a third party might need to know about how a transit system runs.  Additional documentation can be found [here](https://developers.google.com/transit/gtfs/reference/).

# %%
agency = pd.read_csv(datapath + 'gtfs_schedule/agency.txt')
agency
# Out:
#   agency_id                agency_name            agency_url  \
# 0  MTA NYCT  MTA New York City Transit   http://www.mta.info
#
#     agency_timezone agency_lang  agency_phone
# 0  America/New_York          en  718-330-1234

# %% [markdown]
# ## Routes

# %%
routes = pd.read_csv(datapath + 'gtfs_schedule/routes.txt')
routes.sort_index()
# Out:
#    route_id agency_id route_short_name                  route_long_name  \
# 0         1  MTA NYCT                1        Broadway - 7 Avenue Local
# 1         2  MTA NYCT                2                 7 Avenue Express
# 2         3  MTA NYCT                3                 7 Avenue Express
# 3         4  MTA NYCT                4         Lexington Avenue Express
# 4         5  MTA NYCT                5         Lexington Avenue Express
# 5        5X  MTA NYCT               5X         Lexington Avenue Express
# 6         6  MTA NYCT                6           Lexington Avenue Local
# 7        6X  MTA NYCT               6X         Lexington Avenue Express
# 8         7  MTA NYCT                7                   Flushing Local
# 9        7X  MTA NYCT               7X                 Flushing Express
# 10       GS  MTA NYCT                S                    42 St Shuttle
# 11        A  MTA NYCT                A                 8 Avenue Express
# 12        B  MTA NYCT                B                 6 Avenue Express
# 13        C  MTA NYCT                C                   8 Avenue Local
# 14        D  MTA NYCT                D                 6 Avenue Express
# 15        E  MTA NYCT                E                   8 Avenue Local
# 16        F  MTA NYCT                F  Queens Blvd Express/ 6 Av Local
# 17       FS  MTA NYCT                S          Franklin Avenue Shuttle
# 18        G  MTA NYCT                G        Brooklyn-Queens Crosstown
# 19        J  MTA NYCT                J                  Nassau St Local
# 20        L  MTA NYCT                L             14 St-Canarsie Local
# 21        M  MTA NYCT                M   QNS BLVD-6th AVE/ Myrtle Local
# 22        N  MTA NYCT                N                   Broadway Local
# 23        Q  MTA NYCT                Q                 Broadway Express
# 24        R  MTA NYCT                R                   Broadway Local
# 25        H  MTA NYCT                S            Rockaway Park Shuttle
# 26        W  MTA NYCT                W                   Broadway Local
# 27        Z  MTA NYCT                Z                Nassau St Express
# 28       SI  MTA NYCT              SIR            Staten Island Railway
#
#                                            route_desc  route_type  \
# 0   Trains operate between 242 St in the Bronx and...           1
# 1   Trains operate between Wakefield-241 St, Bronx...           1
# 2   Trains operate between 148 St, 7 Av, Manhattan...           1
# 3   Trains operate daily between Woodlawn/Jerome A...           1
# 4   Weekdays daytime, most trains operate between ...           1
# 5   Weekdays daytime, most trains operate between ...           1
# 6   Local trains operate between Pelham Bay Park/B...           1
# 7   Express trains operate between Pelham Bay Park...           1
# 8   Trains operate between Main St-Flushing, Queen...           1
# 9   Trains operate between Main St-Flushing, Queen...           1
# 10  Operates in Manhattan between Grand Central an...           1
# 11  Trains operate between Inwood-207 St, Manhatta...           1
# 12  Trains operate, weekdays only, between 145 St,...           1
# 13  Trains operate between 168 St, Manhattan, and ...           1
# 14  Trains operate, at all times, from 205 Street,...           1
# 15  Trains operate between Jamaica Center (Parsons...           1
# 16  Trains operate at all times between Jamaica, Q...           1
# 17  Train provides full time connecting service be...           1
# 18  Trains operate between Court Square, Queens an...           1
# 19  Trains operate weekdays between Jamaica Center...           1
# 20  Trains operate between 8 Av/14 St, Manhattan, ...           1
# 21  Trains operate between Middle Village-Metropol...           1
# 22  Trains operate from Ditmars Boulevard, Queens,...           1
# 23  Trains operate between Astoria, Queens, and St...           1
# 24  Trains operate local between Forest Hills-71 A...           1
# 25  Service operates at all times between Broad Ch...           1
# 26  Trains operate from Ditmars Boulevard, Queens,...           1
# 27  During weekday rush hours, J and Z trains prov...           1
# 28  Service runs 24 hours a day between the St Geo...           2
#
#                                           route_url route_color  \
# 0    http://web.mta.info/nyct/service/pdf/t1cur.pdf      EE352E
# 1    http://web.mta.info/nyct/service/pdf/t2cur.pdf      EE352E
# 2    http://web.mta.info/nyct/service/pdf/t3cur.pdf      EE352E
# 3    http://web.mta.info/nyct/service/pdf/t4cur.pdf      00933C
# 4    http://web.mta.info/nyct/service/pdf/t5cur.pdf      00933C
# 5    http://web.mta.info/nyct/service/pdf/t5cur.pdf      00933C
# 6    http://web.mta.info/nyct/service/pdf/t6cur.pdf      00933C
# 7    http://web.mta.info/nyct/service/pdf/t6cur.pdf      00A65C
# 8    http://web.mta.info/nyct/service/pdf/t7cur.pdf      B933AD
# 9    http://web.mta.info/nyct/service/pdf/t7cur.pdf      B933AD
# 10   http://web.mta.info/nyct/service/pdf/t0cur.pdf      6D6E71
# 11   http://web.mta.info/nyct/service/pdf/tacur.pdf      2850AD
# 12   http://web.mta.info/nyct/service/pdf/tbcur.pdf      FF6319
# 13   http://web.mta.info/nyct/service/pdf/tccur.pdf      2850AD
# 14   http://web.mta.info/nyct/service/pdf/tdcur.pdf      FF6319
# 15   http://web.mta.info/nyct/service/pdf/tecur.pdf      2850AD
# 16   http://web.mta.info/nyct/service/pdf/tfcur.pdf      FF6319
# 17   http://web.mta.info/nyct/service/pdf/tscur.pdf         NaN
# 18   http://web.mta.info/nyct/service/pdf/tgcur.pdf      6CBE45
# 19   http://web.mta.info/nyct/service/pdf/tjcur.pdf      996633
# 20   http://web.mta.info/nyct/service/pdf/tlcur.pdf      A7A9AC
# 21   http://web.mta.info/nyct/service/pdf/tmcur.pdf      FF6319
# 22   http://web.mta.info/nyct/service/pdf/tncur.pdf      FCCC0A
# 23   http://web.mta.info/nyct/service/pdf/tqcur.pdf      FCCC0A
# 24   http://web.mta.info/nyct/service/pdf/trcur.pdf      FCCC0A
# 25   http://web.mta.info/nyct/service/pdf/thcur.pdf         NaN
# 26   http://web.mta.info/nyct/service/pdf/twcur.pdf      FCCC0A
# 27   http://web.mta.info/nyct/service/pdf/tjcur.pdf      996633
# 28  http://web.mta.info/nyct/service/pdf/sircur.pdf         NaN
#
#    route_text_color
# 0               NaN
# 1
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11           FFFFFF
# 12              NaN
# 13           FFFFFF
# 14              NaN
# 15           FFFFFF
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN

# %% [markdown]
# ## Trips
# A trip is a single journey by a train from one end of a line to the other.

# %%
trips = pd.read_csv(datapath + 'gtfs_schedule/trips.txt').dropna(how='all', axis=1)
trips.query('route_id == "1"').sample(5).sort_index() #[trips.trip_id == '016900_A..S']
# Out:
#     route_id                 service_id  \
# 220        1    ASP18GEN-1037-Sunday-00
# 369        1  ASP18GEN-1038-Saturday-00
# 550        1  ASP18GEN-1038-Saturday-00
# 777        1   ASP18GEN-1087-Weekday-00
# 794        1   ASP18GEN-1087-Weekday-00
#
#                                       trip_id                trip_headsign  \
# 220    ASP18GEN-1037-Sunday-00_119750_1..S03R                  South Ferry
# 369  ASP18GEN-1038-Saturday-00_061500_1..N03R  Van Cortlandt Park - 242 St
# 550  ASP18GEN-1038-Saturday-00_133550_1..S03R                  South Ferry
# 777   ASP18GEN-1087-Weekday-00_075150_1..S03R                  South Ferry
# 794   ASP18GEN-1087-Weekday-00_080150_1..N03R  Van Cortlandt Park - 242 St
#
#      direction_id shape_id
# 220             1  1..S03R
# 369             0  1..N03R
# 550             1  1..S03R
# 777             1  1..S03R
# 794             0  1..N03R

# %% [markdown]
# Lots of information is encoded in the trip ID, so here I parse it all out.

# %%
trip_id_re = re.compile(r'(A|B|(SIR-))((SP)|(FA))(20)?\d{2}(GEN)?-([0-9A-Z]\w?)\d{3}-(\w+)-\d{2}_(\d+)_([0-9A-Z]\w?)\.\.?([NS])(\d{2}(R|X)(\d{3})?)')

def parse_trip_id(trip_id):
  m = re.match(trip_id_re, trip_id)
  if m is None:
    raise ValueError(f'no match: {trip_id}')
  groups = m.groups()
  if groups[7] != groups[10]:
    raise ValueError(f"incongruent id: {trip_id}")
  return {'trip_id': trip_id,
          'division': groups[0],
          'line': groups[7],
          'day_of_week': groups[8],
          'start_time': groups[9],
          'direction': groups[11],
          'trip_path': groups[12]}

# %%
trip_ids = set(trips.trip_id)
parsed_trips = pd.DataFrame(parse_trip_id(trip_id) for trip_id in trip_ids)
parsed_trips = parsed_trips.sort_values(['day_of_week','division','line','direction','start_time']).reset_index(drop=True)
parsed_trips['start_time'] = parsed_trips.start_time.apply(lambda x: time_of_day_from_minutes(int(x)/100))

# %%
parsed_trips.head()
# Out:
#   day_of_week direction division line start_time  \
# 0    Saturday         N        A    1   01:12:00
# 1    Saturday         N        A    1   01:32:00
# 2    Saturday         N        A    1   01:52:00
# 3    Saturday         N        A    1   02:12:00
# 4    Saturday         N        A    1   02:32:00
#
#                                     trip_id trip_path
# 0  ASP18GEN-1038-Saturday-00_007200_1..N03R       03R
# 1  ASP18GEN-1038-Saturday-00_009200_1..N03R       03R
# 2  ASP18GEN-1038-Saturday-00_011200_1..N03R       03R
# 3  ASP18GEN-1038-Saturday-00_013200_1..N03R       03R
# 4  ASP18GEN-1038-Saturday-00_015200_1..N03R       03R

# %% [markdown]
# And here I join the new, parsed data with the published data.

# %%
trips_full = trips.set_index('trip_id').join(parsed_trips.set_index('trip_id'))
trips_full.query("day_of_week == 'Weekday'").sample(10).sort_values('route_id')
# Out:
#                                          route_id                 service_id  \
# trip_id
# ASP18GEN-2097-Weekday-00_074300_2..N01R         2   ASP18GEN-2097-Weekday-00
# ASP18GEN-6085-Weekday-00_103300_6..S03R         6   ASP18GEN-6085-Weekday-00
# ASP18GEN-6085-Weekday-00_032600_6..N01R         6   ASP18GEN-6085-Weekday-00
# ASP18GEN-6085-Weekday-00_106700_6..N03R         6   ASP18GEN-6085-Weekday-00
# ASP18GEN-6085-Weekday-00_113000_6..S01R         6   ASP18GEN-6085-Weekday-00
# ASP18GEN-6085-Weekday-00_115100_6..S01R         6   ASP18GEN-6085-Weekday-00
# ASP18GEN-7058-Weekday-00_054000_7..N97R         7   ASP18GEN-7058-Weekday-00
# BSP18GEN-B080-Weekday-00_036750_B..N45R         B   BSP18GEN-B080-Weekday-00
# BSP18GEN-C049-Weekday-00_041350_C..N04R         C   BSP18GEN-C049-Weekday-00
# ASP18GEN-GS019-Weekday-00_069550_GS.S01R       GS  ASP18GEN-GS019-Weekday-00
#
#                                                         trip_headsign  \
# trip_id
# ASP18GEN-2097-Weekday-00_074300_2..N01R            Wakefield - 241 St
# ASP18GEN-6085-Weekday-00_103300_6..S03R   Brooklyn Bridge - City Hall
# ASP18GEN-6085-Weekday-00_032600_6..N01R               Pelham Bay Park
# ASP18GEN-6085-Weekday-00_106700_6..N03R                   Parkchester
# ASP18GEN-6085-Weekday-00_113000_6..S01R   Brooklyn Bridge - City Hall
# ASP18GEN-6085-Weekday-00_115100_6..S01R   Brooklyn Bridge - City Hall
# ASP18GEN-7058-Weekday-00_054000_7..N97R            Flushing - Main St
# BSP18GEN-B080-Weekday-00_036750_B..N45R             Bedford Park Blvd
# BSP18GEN-C049-Weekday-00_041350_C..N04R                        168 St
# ASP18GEN-GS019-Weekday-00_069550_GS.S01R        Grand Central - 42 St
#
#                                           direction_id shape_id day_of_week  \
# trip_id
# ASP18GEN-2097-Weekday-00_074300_2..N01R              0  2..N01R     Weekday
# ASP18GEN-6085-Weekday-00_103300_6..S03R              1  6..S03R     Weekday
# ASP18GEN-6085-Weekday-00_032600_6..N01R              0  6..N01R     Weekday
# ASP18GEN-6085-Weekday-00_106700_6..N03R              0  6..N03R     Weekday
# ASP18GEN-6085-Weekday-00_113000_6..S01R              1  6..S01R     Weekday
# ASP18GEN-6085-Weekday-00_115100_6..S01R              1  6..S01R     Weekday
# ASP18GEN-7058-Weekday-00_054000_7..N97R              0  7..N97R     Weekday
# BSP18GEN-B080-Weekday-00_036750_B..N45R              0  B..N45R     Weekday
# BSP18GEN-C049-Weekday-00_041350_C..N04R              0  C..N04R     Weekday
# ASP18GEN-GS019-Weekday-00_069550_GS.S01R             1  GS.S01R     Weekday
#
#                                          direction division line start_time  \
# trip_id
# ASP18GEN-2097-Weekday-00_074300_2..N01R          N        A    2   12:23:00
# ASP18GEN-6085-Weekday-00_103300_6..S03R          S        A    6   17:13:00
# ASP18GEN-6085-Weekday-00_032600_6..N01R          N        A    6   05:26:00
# ASP18GEN-6085-Weekday-00_106700_6..N03R          N        A    6   17:47:00
# ASP18GEN-6085-Weekday-00_113000_6..S01R          S        A    6   18:50:00
# ASP18GEN-6085-Weekday-00_115100_6..S01R          S        A    6   19:11:00
# ASP18GEN-7058-Weekday-00_054000_7..N97R          N        A    7   09:00:00
# BSP18GEN-B080-Weekday-00_036750_B..N45R          N        B    B   06:07:30
# BSP18GEN-C049-Weekday-00_041350_C..N04R          N        B    C   06:53:30
# ASP18GEN-GS019-Weekday-00_069550_GS.S01R         S        A   GS   11:35:30
#
#                                          trip_path
# trip_id
# ASP18GEN-2097-Weekday-00_074300_2..N01R        01R
# ASP18GEN-6085-Weekday-00_103300_6..S03R        03R
# ASP18GEN-6085-Weekday-00_032600_6..N01R        01R
# ASP18GEN-6085-Weekday-00_106700_6..N03R        03R
# ASP18GEN-6085-Weekday-00_113000_6..S01R        01R
# ASP18GEN-6085-Weekday-00_115100_6..S01R        01R
# ASP18GEN-7058-Weekday-00_054000_7..N97R        97R
# BSP18GEN-B080-Weekday-00_036750_B..N45R        45R
# BSP18GEN-C049-Weekday-00_041350_C..N04R        04R
# ASP18GEN-GS019-Weekday-00_069550_GS.S01R       01R

# %% [markdown]
# ## Stop Times
# Each trip has published arrive and depart times for every stop, which are in this table.

# %%
stop_times = pd.read_csv(datapath + 'gtfs_schedule/stop_times.txt').dropna(how='all', axis=1)
stop_times['route_id'] = stop_times.trip_id.str.extract('_([^_]*)\.\.')
stop_times.query('trip_id == "ASP18GEN-1087-Weekday-00_090300_1..N03R"').head()
# Out:
#                                        trip_id arrival_time departure_time  \
# 34477  ASP18GEN-1087-Weekday-00_090300_1..N03R     15:03:00       15:03:00
# 34478  ASP18GEN-1087-Weekday-00_090300_1..N03R     15:05:30       15:05:30
# 34479  ASP18GEN-1087-Weekday-00_090300_1..N03R     15:06:30       15:06:30
# 34480  ASP18GEN-1087-Weekday-00_090300_1..N03R     15:07:30       15:07:30
# 34481  ASP18GEN-1087-Weekday-00_090300_1..N03R     15:08:30       15:08:30
#
#       stop_id  stop_sequence  pickup_type  drop_off_type route_id
# 34477    142N              1            0              0        1
# 34478    139N              2            0              0        1
# 34479    138N              3            0              0        1
# 34480    137N              4            0              0        1
# 34481    136N              5            0              0        1

# %% [markdown]
# ## Stops
# Each stop has additional metadata, like lat/long, which can be found here.

# %%
stops = pd.read_csv(datapath + 'gtfs_schedule/stops.txt').dropna(how='all', axis=1)
stops.query('stop_id in ["G06N","G07N"]').sort_index(ascending=False)
# Out:
#     stop_id                               stop_name   stop_lat   stop_lon  \
# 967    G07N                      Jamaica - Van Wyck  40.702566 -73.816859
# 964    G06N  Sutphin Blvd - Archer Av - JFK Airport  40.700486 -73.807969
#
#      location_type parent_station
# 967              0            G07
# 964              0            G06

# %%
stops[stops.stop_id == 'A59S']
# Out:
#     stop_id stop_name   stop_lat   stop_lon  location_type parent_station
# 677    A59S     80 St  40.679371 -73.858992              0            A59

# %% [markdown]
# ## Other tables

# %%
calendar_dates = pd.read_csv(datapath + 'gtfs_schedule/calendar_dates.txt')
calendar_dates.head()
# Out:
#                 service_id      date  exception_type
# 0  ASP18GEN-1037-Sunday-00  20180903               1
# 1  ASP18GEN-2048-Sunday-00  20180903               1
# 2  ASP18GEN-3041-Sunday-00  20180903               1
# 3  ASP18GEN-4049-Sunday-00  20180903               1
# 4  ASP18GEN-5048-Sunday-00  20180903               1

# %%
calendar = pd.read_csv(datapath + 'gtfs_schedule/calendar.txt')
calendar.head()
# Out:
#                 service_id  monday  tuesday  wednesday  thursday  friday  \
# 0  ASP18GEN-1037-Sunday-00       0        0          0         0       0
# 1  ASP18GEN-2048-Sunday-00       0        0          0         0       0
# 2  ASP18GEN-3041-Sunday-00       0        0          0         0       0
# 3  ASP18GEN-4049-Sunday-00       0        0          0         0       0
# 4  ASP18GEN-5048-Sunday-00       0        0          0         0       0
#
#    saturday  sunday  start_date  end_date
# 0         0       1    20180624  20181028
# 1         0       1    20180624  20181028
# 2         0       1    20180624  20181028
# 3         0       1    20180624  20181028
# 4         0       1    20180624  20181028

# %%
transfers = pd.read_csv(datapath + 'gtfs_schedule/transfers.txt')
transfers.head()
# Out:
#   from_stop_id to_stop_id  transfer_type  min_transfer_time
# 0          101        101              2                180
# 1          103        103              2                180
# 2          104        104              2                180
# 3          106        106              2                180
# 4          107        107              2                180

# %%
shapes = pd.read_csv(datapath + 'gtfs_schedule/shapes.txt').dropna(how='all', axis=1)
shapes.head()
# Out:
#   shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0  1..N03R     40.702068    -74.013664                  0
# 1  1..N03R     40.703199    -74.014792                  1
# 2  1..N03R     40.703226    -74.014820                  2
# 3  1..N03R     40.703253    -74.014846                  3
# 4  1..N03R     40.703280    -74.014870                  4

# %% [markdown]
# # historical GTFS realtime data
# Realtime data is delivered via a protocol called GTFS-RT, which looks almost nothing like the GTFS protocol above.  It is delivered via a Google-developed format called protobuf, which is essentially a more efficient but non-human-readable alternative to JSON.

# %%
from google.transit import gtfs_realtime_pb2
from python_src import nyct_subway_pb2
import os
import re
import pandas as pd
import datetime
import time
from protobuf_to_dict import protobuf_to_dict

# %%
basepath = datapath + 'gtfs_realtime/august_2018/20180801/'
filename = 'gtfs_ace_20180801_041946.gtfs'
with open(basepath + filename, 'rb') as f:
  content = f.read()

feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(content)
# Out:
# 33908

# %% [markdown]
# ### enumerated types

# %%
vehicle_stop_statuses = {v.number: v.name for v in gtfs_realtime_pb2._VEHICLEPOSITION_VEHICLESTOPSTATUS.values}
vehicle_stop_statuses
# Out:
# {0: 'INCOMING_AT', 1: 'STOPPED_AT', 2: 'IN_TRANSIT_TO'}

# %%
directions = {v.number: v.name for v in nyct_subway_pb2._NYCTTRIPDESCRIPTOR_DIRECTION.values}
directions
# Out:
# {1: 'NORTH', 2: 'EAST', 3: 'SOUTH', 4: 'WEST'}

# %%
schedule_relationships = {v.number: v.name for v in gtfs_realtime_pb2._TRIPDESCRIPTOR_SCHEDULERELATIONSHIP.values}
schedule_relationships
# Out:
# {0: 'SCHEDULED', 1: 'ADDED', 2: 'UNSCHEDULED', 3: 'CANCELED'}

# %% [markdown]
# ### tracing one trip across lots of trip_updates

# %%
def grouped_entities(feed_message):
  if len(feed_message.entity) %2 != 0:
    raise ValueError('odd number of entities')
  for e1, e2 in zip(feed_message.entity[::2], feed_message.entity[1::2]):
    yield e1.trip_update, e2.vehicle
  return

# %%
l = []
trip_id = '025700_E..N' # started 257 minutes after midnight, or at 04:17 - E train - heading "north" (toward Queens)
for filename in sorted(os.listdir(basepath)):
  if filename.split('_')[1] != 'ace':
    continue
  with open(basepath + filename, 'rb') as f:
    content = f.read()
  feed_message = gtfs_realtime_pb2.FeedMessage()
  try:
    feed_message.ParseFromString(content)
  except:
    continue
  
  d = {}
  for e in feed_message.entity: # only one of these will match the trip_id (in theory)
    if e.trip_update.trip.trip_id == trip_id:
      d = {
          'timestamp': time_of_day_from_unix_ts(feed_message.header.timestamp),
          **{u.stop_id: time_of_day_from_unix_ts(u.arrival.time) for u in e.trip_update.stop_time_update}
      }
    
  if d:
    l.append(d)

# %%
scheds = pd.DataFrame(l).set_index('timestamp')
timetable = scheds.drop_duplicates().sort_values(scheds.index[0], axis=1)
timetable.columns = [stops.set_index('stop_id').loc[stop_id].stop_name for stop_id in timetable.columns]
timetable.head(15)
# Out:
#            Canal St Spring St    W 4 St     14 St     23 St  \
# timestamp
# 04:19:46   04:19:22  04:20:30  04:22:30  04:24:30  04:26:00
# 04:20:01   04:19:37  04:20:42  04:22:42  04:24:42  04:26:12
# 04:20:16        NaN  04:19:50  04:21:50  04:23:50  04:25:20
# 04:20:31        NaN  04:20:12  04:21:50  04:23:50  04:25:20
# 04:20:46        NaN  04:20:22  04:21:50  04:23:50  04:25:20
# 04:21:01        NaN  04:20:37  04:21:50  04:23:50  04:25:20
# 04:21:16        NaN  04:20:47  04:21:54  04:23:54  04:25:24
# 04:21:31        NaN  04:21:12  04:22:18  04:24:18  04:25:48
# 04:21:46        NaN  04:21:22  04:22:30  04:24:30  04:26:00
# 04:22:01        NaN  04:21:37  04:22:42  04:24:42  04:26:12
# 04:22:16        NaN  04:21:42  04:22:54  04:24:54  04:26:24
# 04:22:31        NaN       NaN  04:22:12  04:23:54  04:25:24
# 04:22:46        NaN       NaN  04:22:22  04:23:54  04:25:24
# 04:23:01        NaN       NaN  04:22:37  04:23:54  04:25:24
# 04:23:16        NaN       NaN  04:22:47  04:23:54  04:25:24
#
#           34 St - Penn Station 42 St - Port Authority Bus Terminal     50 St  \
# timestamp
# 04:19:46              04:28:00                            04:29:00  04:30:30
# 04:20:01              04:28:12                            04:29:12  04:30:42
# 04:20:16              04:27:20                            04:28:20  04:29:50
# 04:20:31              04:27:20                            04:28:20  04:29:50
# 04:20:46              04:27:20                            04:28:20  04:29:50
# 04:21:01              04:27:20                            04:28:20  04:29:50
# 04:21:16              04:27:24                            04:28:24  04:29:54
# 04:21:31              04:27:48                            04:28:48  04:30:18
# 04:21:46              04:28:00                            04:29:00  04:30:30
# 04:22:01              04:28:12                            04:29:12  04:30:42
# 04:22:16              04:28:24                            04:29:24  04:30:54
# 04:22:31              04:27:24                            04:28:24  04:29:54
# 04:22:46              04:27:24                            04:28:24  04:29:54
# 04:23:01              04:27:24                            04:28:24  04:29:54
# 04:23:16              04:27:24                            04:28:24  04:29:54
#
#                7 Av 5 Av/53 St Lexington Av/53 St  Court Sq Queens Plaza  \
# timestamp
# 04:19:46   04:32:00   04:33:00           04:34:30  04:37:30     04:39:00
# 04:20:01   04:32:12   04:33:12           04:34:42  04:37:42     04:39:12
# 04:20:16   04:31:20   04:32:20           04:33:50  04:36:50     04:38:20
# 04:20:31   04:31:20   04:32:20           04:33:50  04:36:50     04:38:20
# 04:20:46   04:31:20   04:32:20           04:33:50  04:36:50     04:38:20
# 04:21:01   04:31:20   04:32:20           04:33:50  04:36:50     04:38:20
# 04:21:16   04:31:24   04:32:24           04:33:54  04:36:54     04:38:24
# 04:21:31   04:31:48   04:32:48           04:34:18  04:37:18     04:38:48
# 04:21:46   04:32:00   04:33:00           04:34:30  04:37:30     04:39:00
# 04:22:01   04:32:12   04:33:12           04:34:42  04:37:42     04:39:12
# 04:22:16   04:32:24   04:33:24           04:34:54  04:37:54     04:39:24
# 04:22:31   04:31:24   04:32:24           04:33:54  04:36:54     04:38:24
# 04:22:46   04:31:24   04:32:24           04:33:54  04:36:54     04:38:24
# 04:23:01   04:31:24   04:32:24           04:33:54  04:36:54     04:38:24
# 04:23:16   04:31:24   04:32:24           04:33:54  04:36:54     04:38:24
#
#           Jackson Hts - Roosevelt Av Forest Hills - 71 Av  \
# timestamp
# 04:19:46                    04:45:15             04:54:00
# 04:20:01                    04:45:27             04:54:12
# 04:20:16                    04:44:35             04:53:20
# 04:20:31                    04:44:35             04:53:20
# 04:20:46                    04:44:35             04:53:20
# 04:21:01                    04:44:35             04:53:20
# 04:21:16                    04:44:39             04:53:24
# 04:21:31                    04:45:03             04:53:48
# 04:21:46                    04:45:15             04:54:00
# 04:22:01                    04:45:27             04:54:12
# 04:22:16                    04:45:39             04:54:24
# 04:22:31                    04:44:39             04:53:24
# 04:22:46                    04:44:39             04:53:24
# 04:23:01                    04:44:39             04:53:24
# 04:23:16                    04:44:39             04:53:24
#
#           Kew Gardens - Union Tpke Jamaica - Van Wyck  \
# timestamp
# 04:19:46                  04:58:15           05:04:15
# 04:20:01                  04:58:27           05:04:27
# 04:20:16                  04:57:35           05:03:35
# 04:20:31                  04:57:35           05:03:35
# 04:20:46                  04:57:35           05:03:35
# 04:21:01                  04:57:35           05:03:35
# 04:21:16                  04:57:39           05:03:39
# 04:21:31                  04:58:03           05:04:03
# 04:21:46                  04:58:15           05:04:15
# 04:22:01                  04:58:27           05:04:27
# 04:22:16                  04:58:39           05:04:39
# 04:22:31                  04:57:39           05:03:39
# 04:22:46                  04:57:39           05:03:39
# 04:23:01                  04:57:39           05:03:39
# 04:23:16                  04:57:39           05:03:39
#
#           Sutphin Blvd - Archer Av - JFK Airport  \
# timestamp
# 04:19:46                                05:08:45
# 04:20:01                                05:08:57
# 04:20:16                                05:08:05
# 04:20:31                                05:08:05
# 04:20:46                                05:08:05
# 04:21:01                                05:08:05
# 04:21:16                                05:08:09
# 04:21:31                                05:08:33
# 04:21:46                                05:08:45
# 04:22:01                                05:08:57
# 04:22:16                                05:09:09
# 04:22:31                                05:08:09
# 04:22:46                                05:08:09
# 04:23:01                                05:08:09
# 04:23:16                                05:08:09
#
#           Jamaica Center - Parsons/Archer
# timestamp
# 04:19:46                         05:13:00
# 04:20:01                         05:13:12
# 04:20:16                         05:12:20
# 04:20:31                         05:12:20
# 04:20:46                         05:12:20
# 04:21:01                         05:12:20
# 04:21:16                         05:12:24
# 04:21:31                         05:12:48
# 04:21:46                         05:13:00
# 04:22:01                         05:13:12
# 04:22:16                         05:13:24
# 04:22:31                         05:12:24
# 04:22:46                         05:12:24
# 04:23:01                         05:12:24
# 04:23:16                         05:12:24

# %% [markdown]
# ### Examples of protobuf objects

# %%
feed.entity[44].trip_update.stop_time_update[0]
# Out:
# arrival {
#   time: 1533111562
# }
# departure {
#   time: 1533111562
# }
# stop_id: "A34N"
# schedule_relationship: SCHEDULED
# [nyct_stop_time_update] {
#   scheduled_track: "A2"
#   actual_track: "A2"
# }

# %%
time_of_day_from_unix_ts(feed.entity[44].trip_update.stop_time_update[0].arrival.time)
# Out:
# datetime.time(4, 19, 22)

# %%
feed.entity[45].vehicle
# Out:
# trip {
#   trip_id: "025700_E..N"
#   start_date: "20180801"
#   route_id: "E"
#   [nyct_trip_descriptor] {
#     train_id: "1E 0408+ WTC/P-A"
#     is_assigned: true
#     direction: NORTH
#   }
# }
# current_stop_sequence: 1
# current_status: STOPPED_AT
# timestamp: 1533111569

# %%
time_of_day_from_unix_ts(feed.entity[45].vehicle.timestamp)
# Out:
# datetime.time(4, 19, 29)

# %% [markdown]
# ### Finding closest scheduled trip
# Because the trip_ids in the realtime data feed don't match up with the ones in the schedule, we have to make an educated guess.  I do this by searching the schedule for trips on the same day, on the same line, and in the same direction, and then picking the one with the start time that is closest to the actual start time.

# %%
short_trip_id_re = re.compile(r'(\d{6})_(\w)..(\w)')
def parse_short_trip_id(trip_id):
  m = re.match(short_trip_id_re, trip_id)
  if m is None:
    raise ValueError(f'no match: {trip_id}')
  groups = m.groups()
  return {'timestamp': groups[0],
          'line': groups[1],
          'direction': groups[2]}

# %%
feed.entity[45].vehicle
# Out:
# trip {
#   trip_id: "025700_E..N"
#   start_date: "20180801"
#   route_id: "E"
#   [nyct_trip_descriptor] {
#     train_id: "1E 0408+ WTC/P-A"
#     is_assigned: true
#     direction: NORTH
#   }
# }
# current_stop_sequence: 1
# current_status: STOPPED_AT
# timestamp: 1533111569

# %%
start_date = feed.entity[45].vehicle.trip.start_date
day_of_week_from_datestamp(start_date)

days =  {0: 'Weekday',
         1: 'Weekday',
         2: 'Weekday',
         3: 'Weekday',
         4: 'Weekday',
         5: 'Saturday',
         6: 'Sunday'}

days[day_of_week_from_datestamp(start_date)]
# Out:
# 'Weekday'

# %%
tid = feed.entity[45].vehicle.trip.trip_id
short_trip_id_params = parse_short_trip_id(tid)
short_trip_id_params
# Out:
# {'timestamp': '025700', 'line': 'E', 'direction': 'N'}

# %%
timestamp = short_trip_id_params['timestamp']
line = short_trip_id_params['line']
direction = short_trip_id_params['direction']

day_of_week = days[day_of_week_from_datestamp(start_date)]
time_of_day = time_of_day_from_minutes(int(timestamp)/100)

relevant_trips = trips_full[(trips_full.line == line) & (trips_full.direction == direction) & (trips_full.day_of_week == day_of_week)]
closest_trip_id = relevant_trips.start_time.apply(lambda ts: timediff(ts, time_of_day)).idxmin()
closest_trip = relevant_trips.loc[closest_trip_id]
closest_trip
# Out:
# route_id                                       E
# service_id              BSP18GEN-E070-Weekday-00
# trip_headsign    Jamaica Center - Parsons/Archer
# direction_id                                   0
# shape_id                                 E..N05R
# day_of_week                              Weekday
# direction                                      N
# division                                       B
# line                                           E
# start_time                              04:08:30
# trip_path                                    05R
# Name: BSP18GEN-E070-Weekday-00_024850_E..N05R, dtype: object

# %%
time_of_day
# Out:
# datetime.time(4, 17)

# %% [markdown]
# ### upcoming stop

# %%
schedule = stop_times.set_index('trip_id').loc[closest_trip_id]
schedule.head()
# Out:
#                                         arrival_time departure_time stop_id  \
# trip_id
# BSP18GEN-E070-Weekday-00_024850_E..N05R     04:08:30       04:08:30    E01N
# BSP18GEN-E070-Weekday-00_024850_E..N05R     04:10:30       04:10:30    A34N
# BSP18GEN-E070-Weekday-00_024850_E..N05R     04:12:00       04:12:00    A33N
# BSP18GEN-E070-Weekday-00_024850_E..N05R     04:14:00       04:14:00    A32N
# BSP18GEN-E070-Weekday-00_024850_E..N05R     04:16:00       04:16:00    A31N
#
#                                          stop_sequence  pickup_type  \
# trip_id
# BSP18GEN-E070-Weekday-00_024850_E..N05R              1            0
# BSP18GEN-E070-Weekday-00_024850_E..N05R              2            0
# BSP18GEN-E070-Weekday-00_024850_E..N05R              3            0
# BSP18GEN-E070-Weekday-00_024850_E..N05R              4            0
# BSP18GEN-E070-Weekday-00_024850_E..N05R              5            0
#
#                                          drop_off_type route_id
# trip_id
# BSP18GEN-E070-Weekday-00_024850_E..N05R              0        E
# BSP18GEN-E070-Weekday-00_024850_E..N05R              0        E
# BSP18GEN-E070-Weekday-00_024850_E..N05R              0        E
# BSP18GEN-E070-Weekday-00_024850_E..N05R              0        E
# BSP18GEN-E070-Weekday-00_024850_E..N05R              0        E

# %%
feed.entity[45].vehicle
# Out:
# trip {
#   trip_id: "025700_E..N"
#   start_date: "20180801"
#   route_id: "E"
#   [nyct_trip_descriptor] {
#     train_id: "1E 0408+ WTC/P-A"
#     is_assigned: true
#     direction: NORTH
#   }
# }
# current_stop_sequence: 1
# current_status: STOPPED_AT
# timestamp: 1533111569

# %%
schedule[schedule.stop_sequence == feed.entity[45].vehicle.current_stop_sequence]
# Out:
#                                         arrival_time departure_time stop_id  \
# trip_id
# BSP18GEN-E070-Weekday-00_024850_E..N05R     04:08:30       04:08:30    E01N
#
#                                          stop_sequence  pickup_type  \
# trip_id
# BSP18GEN-E070-Weekday-00_024850_E..N05R              1            0
#
#                                          drop_off_type route_id
# trip_id
# BSP18GEN-E070-Weekday-00_024850_E..N05R              0        E

# %% [markdown]
# ### all extant trips at a given time

# %%
trips = pd.DataFrame([(tu.trip_update.trip.trip_id, v.vehicle.current_stop_sequence) for tu, v in zip(feed.entity[::2], feed.entity[1::2])], columns=['trip_id', 'current_stop_sequence'])
trips['start_times'] = (trips.trip_id.str[:6].astype(int)/100).apply(time_of_day_from_minutes)

# %%
trips.sort_values('start_times')
# Out:
#         trip_id  current_stop_sequence      start_times
# 1   016500_A..N                     52         02:45:00
# 0   016900_A..S                     47         02:49:00
# 2   018500_A..N                     38         03:05:00
# 3   018950_A..S                     43         03:09:30
# 19  019200_E..S                     30         03:12:00
# 4   020500_A..N                     26         03:25:00
# 5   020900_A..S                     31         03:29:00
# 21  022050_E..N                     26         03:40:30
# 18  022426_E..S                     18  03:44:15.600000
# 6   022500_A..N                     15         03:45:00
# 7   022900_A..S                     19         03:49:00
# 20  023200_E..N                     13         03:52:00
# 8   024500_A..N                      5         04:05:00
# 12  024900_A..S                      7         04:09:00
# 32  024950_F..N                      3         04:09:30
# 25  025100_E..S                      4         04:11:00
# 27  025200_H..S                      5         04:12:00
# 28  025500_H..N                      3         04:15:00
# 22  025700_E..N                      1         04:17:00
# 33  026000_F..S                      0         04:20:00
# 9   026000_A..S                      0         04:20:00
# 23  026250_E..S                      0         04:22:30
# 11  026500_A..N                      0         04:25:00
# 10  026500_A..N                      0         04:25:00
# 29  026700_H..S                      0         04:27:00
# 24  026850_E..N                      0         04:28:30
# 13  026950_A..S                      0         04:29:30
# 34  026950_F..N                      0         04:29:30
# 26  027250_E..S                      0         04:32:30
# 30  027500_H..N                      0         04:35:00
# 16  028000_A..N                      0         04:40:00
# 14  028000_A..S                      0         04:40:00
# 35  028000_F..S                      0         04:40:00
# 31  028400_H..S                      0         04:44:00
# 15  028500_A..N                      0         04:45:00
# 17  028950_A..S                      0         04:49:30
# 36  028950_F..N                      0         04:49:30

# %% [markdown]
# ### ~~ Everything after this is unmaintained ~~

# %%
# checking for stop_ids in vehicle updates - there are none 
line_groups = []
basepath = '/home/tanner/Documents/transit/gtfs_realtime/august_2018/20180801/'
for filename in sorted(os.listdir(basepath)):
  line_group = filename.split('_')[1]
  if line_group not in line_groups:
    print('parsing group', line_group)
    line_groups.append(line_group)
    
  with open(basepath + filename, 'rb') as f:
    content = f.read()
  feed = gtfs_realtime_pb2.FeedMessage()
  try:
    feed.ParseFromString(content)
  except:
    print('error parsing', filename)
    continue
  
  if any(e.vehicle.stop_id for e in feed.entity):
    print(filename, 'has stop_ids')
# Out:
# parsing group ace
# error parsing gtfs_ace_20180801_085717.gtfs
# error parsing gtfs_ace_20180801_181116.gtfs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-8ea7f527f5ac> in <module>()
#      10   with open(basepath + filename, 'rb') as f:
#      11     content = f.read()
# ---> 12   feed = gtfs_realtime_pb2.FeedMessage()
#      13   try:
#      14     feed.ParseFromString(content)
#
# KeyboardInterrupt:

# %%
basepath = '/home/tanner/Documents/transit/gtfs_realtime/august_2018/20180801/'
for filename in sorted(os.listdir(basepath)):
  with open(basepath + filename, 'rb') as f:
    content = f.read()
  feed = gtfs_realtime_pb2.FeedMessage()
  try:
    feed.ParseFromString(content)
  except:
    print('error parsing', filename)
    continue
 
  for e in feed.entity:
    if str(e.alert):
      print(e.alert)
      raise StopIteration()
# Out:
# error parsing gtfs_bdfm_20180801_052206.gtfs
# error parsing gtfs_bdfm_20180801_054951.gtfs
# error parsing gtfs_bdfm_20180801_060906.gtfs
# error parsing gtfs_bdfm_20180801_210708.gtfs
# error parsing gtfs_bdfm_20180801_213453.gtfs
# error parsing gtfs_bdfm_20180801_213753.gtfs
# error parsing gtfs_bdfm_20180801_213823.gtfs
# error parsing gtfs_bdfm_20180801_220053.gtfs
# error parsing gtfs_bdfm_20180801_231853.gtfs
# error parsing gtfs_nqrw_20180801_054424.gtfs
# error parsing gtfs_nqrw_20180801_055654.gtfs
# error parsing gtfs_nqrw_20180801_060009.gtfs
# error parsing gtfs_nqrw_20180801_060854.gtfs
# error parsing gtfs_nqrw_20180801_065155.gtfs
# error parsing gtfs_nqrw_20180801_070124.gtfs
# error parsing gtfs_nqrw_20180801_071654.gtfs
# error parsing gtfs_nqrw_20180801_090124.gtfs
# error parsing gtfs_nqrw_20180801_093340.gtfs
# error parsing gtfs_nqrw_20180801_093409.gtfs
# error parsing gtfs_nqrw_20180801_093924.gtfs
# error parsing gtfs_nqrw_20180801_094824.gtfs
# error parsing gtfs_nqrw_20180801_094854.gtfs
# error parsing gtfs_nqrw_20180801_095009.gtfs
# error parsing gtfs_nqrw_20180801_100324.gtfs
# error parsing gtfs_nqrw_20180801_101924.gtfs
# error parsing gtfs_nqrw_20180801_103039.gtfs
# error parsing gtfs_nqrw_20180801_115342.gtfs
# error parsing gtfs_nqrw_20180801_125612.gtfs
# error parsing gtfs_nqrw_20180801_131312.gtfs
# error parsing gtfs_nqrw_20180801_141857.gtfs
# error parsing gtfs_nqrw_20180801_151342.gtfs
# error parsing gtfs_nqrw_20180801_153127.gtfs
# error parsing gtfs_nqrw_20180801_155312.gtfs
# error parsing gtfs_nqrw_20180801_161242.gtfs
# error parsing gtfs_nqrw_20180801_183742.gtfs
# error parsing gtfs_nqrw_20180801_190157.gtfs
# error parsing gtfs_nqrw_20180801_205342.gtfs
# error parsing gtfs_nqrw_20180801_205357.gtfs
# error parsing gtfs_nqrw_20180801_210557.gtfs

# %%
vehicles = []
for e in feed.entity:
  if str(e.vehicle):
    vehicles.append({
      'id': e.id,
      'trip_id': e.vehicle.trip.trip_id,
      'start_date': e.vehicle.trip.start_date,
      'route_id': e.vehicle.trip.route_id,
      'direction': e.vehicle.trip.ListFields()[-1][-1].direction,
      'current_stop_sequence': e.vehicle.current_stop_sequence,
      'current_status': e.vehicle.current_status,
      'timestamp': e.vehicle.timestamp
    })
df = pd.DataFrame(vehicles)

# %%
df.sort_values(['route_id','direction','current_stop_sequence'])
# Out:
#     current_status  current_stop_sequence  direction        id route_id  \
# 10               2                      0          1  26000022        A
# 11               2                      0          1  26000024        A
# 15               2                      0          1  26000032        A
# 16               2                      0          1  26000034        A
# 8                1                      5          1  26000018        A
# 6                1                     15          1  26000014        A
# 4                1                     26          1  26000010        A
# 2                1                     38          1  26000006        A
# 1                1                     52          1  26000004        A
# 9                0                      0          3  26000020        A
# 13               2                      0          3  26000028        A
# 14               2                      0          3  26000030        A
# 17               2                      0          3  26000036        A
# 12               1                      7          3  26000026        A
# 7                1                     19          3  26000016        A
# 5                1                     31          3  26000012        A
# 3                1                     43          3  26000008        A
# 0                1                     47          3  26000002        A
# 24               2                      0          1  28000014        E
# 22               1                      1          1  28000010        E
# 20               1                     13          1  28000006        E
# 21               1                     26          1  28000008        E
# 23               2                      0          3  28000012        E
# 26               2                      0          3  28000018        E
# 25               1                      4          3  28000016        E
# 18               1                     18          3  28000002        E
# 19               1                     30          3  28000004        E
# 34               2                      0          1  57000006       FS
# 36               2                      0          1  57000010       FS
# 32               1                      3          1  57000002       FS
# 33               0                      0          3  57000004       FS
# 35               2                      0          3  57000008       FS
# 30               2                      0          1  56000008        H
# 28               1                      3          1  56000004        H
# 29               2                      0          3  56000006        H
# 31               2                      0          3  56000010        H
# 27               1                      5          3  56000002        H
#
#    start_date   timestamp      trip_id
# 10   20180801  1533111583  026500_A..N
# 11   20180801  1533111583  026500_A..N
# 15   20180801  1533111583  028500_A..N
# 16   20180801  1533111583  028000_A..N
# 8    20180801  1533111577  024500_A..N
# 6    20180801  1533111537  022500_A..N
# 4    20180801  1533111517  020500_A..N
# 2    20180801  1533111577  018500_A..N
# 1    20180801  1533111577  016500_A..N
# 9    20180801  1533111583  026000_A..S
# 13   20180801  1533111583  026950_A..S
# 14   20180801  1533111583  028000_A..S
# 17   20180801  1533111583  028950_A..S
# 12   20180801  1533111577  024900_A..S
# 7    20180801  1533111577  022900_A..S
# 5    20180801  1533111577  020900_A..S
# 3    20180801  1533111577  018950_A..S
# 0    20180801  1533111577  016900_A..S
# 24   20180801  1533111570  026850_E..N
# 22   20180801  1533111569  025700_E..N
# 20   20180801  1533111537  023200_E..N
# 21   20180801  1533111562  022050_E..N
# 23   20180801  1533111570  026250_E..S
# 26   20180801  1533111570  027250_E..S
# 25   20180801  1533111562  025100_E..S
# 18   20180801  1533111562  022426_E..S
# 19   20180801  1533111547  019200_E..S
# 34   20180801  1533111571  026950_F..N
# 36   20180801  1533111571  028950_F..N
# 32   20180801  1533111571  024950_F..N
# 33   20180801  1533111571  026000_F..S
# 35   20180801  1533111571  028000_F..S
# 30   20180801  1533111571  027500_H..N
# 28   20180801  1533111562  025500_H..N
# 29   20180801  1533111571  026700_H..S
# 31   20180801  1533111571  028400_H..S
# 27   20180801  1533111562  025200_H..S

# %%
df.sort_values('timestamp')
# Out:
#     current_status  current_stop_sequence        id route_id start_date  \
# 4                1                     26  26000010        A   20180801
# 20               1                     13  28000006        E   20180801
# 6                1                     15  26000014        A   20180801
# 19               1                     30  28000004        E   20180801
# 21               1                     26  28000008        E   20180801
# 25               1                      4  28000016        E   20180801
# 27               1                      5  56000002        H   20180801
# 18               1                     18  28000002        E   20180801
# 28               1                      3  56000004        H   20180801
# 22               1                      1  28000010        E   20180801
# 26               2                      0  28000018        E   20180801
# 24               2                      0  28000014        E   20180801
# 23               2                      0  28000012        E   20180801
# 29               2                      0  56000006        H   20180801
# 31               2                      0  56000010        H   20180801
# 32               1                      3  57000002       FS   20180801
# 33               0                      0  57000004       FS   20180801
# 34               2                      0  57000006       FS   20180801
# 30               2                      0  56000008        H   20180801
# 36               2                      0  57000010       FS   20180801
# 35               2                      0  57000008       FS   20180801
# 0                1                     47  26000002        A   20180801
# 1                1                     52  26000004        A   20180801
# 2                1                     38  26000006        A   20180801
# 3                1                     43  26000008        A   20180801
# 5                1                     31  26000012        A   20180801
# 12               1                      7  26000026        A   20180801
# 7                1                     19  26000016        A   20180801
# 8                1                      5  26000018        A   20180801
# 17               2                      0  26000036        A   20180801
# 11               2                      0  26000024        A   20180801
# 13               2                      0  26000028        A   20180801
# 14               2                      0  26000030        A   20180801
# 15               2                      0  26000032        A   20180801
# 16               2                      0  26000034        A   20180801
# 10               2                      0  26000022        A   20180801
# 9                0                      0  26000020        A   20180801
#
#      timestamp      trip_id
# 4   1533111517  020500_A..N
# 20  1533111537  023200_E..N
# 6   1533111537  022500_A..N
# 19  1533111547  019200_E..S
# 21  1533111562  022050_E..N
# 25  1533111562  025100_E..S
# 27  1533111562  025200_H..S
# 18  1533111562  022426_E..S
# 28  1533111562  025500_H..N
# 22  1533111569  025700_E..N
# 26  1533111570  027250_E..S
# 24  1533111570  026850_E..N
# 23  1533111570  026250_E..S
# 29  1533111571  026700_H..S
# 31  1533111571  028400_H..S
# 32  1533111571  024950_F..N
# 33  1533111571  026000_F..S
# 34  1533111571  026950_F..N
# 30  1533111571  027500_H..N
# 36  1533111571  028950_F..N
# 35  1533111571  028000_F..S
# 0   1533111577  016900_A..S
# 1   1533111577  016500_A..N
# 2   1533111577  018500_A..N
# 3   1533111577  018950_A..S
# 5   1533111577  020900_A..S
# 12  1533111577  024900_A..S
# 7   1533111577  022900_A..S
# 8   1533111577  024500_A..N
# 17  1533111583  028950_A..S
# 11  1533111583  026500_A..N
# 13  1533111583  026950_A..S
# 14  1533111583  028000_A..S
# 15  1533111583  028500_A..N
# 16  1533111583  028000_A..N
# 10  1533111583  026500_A..N
# 9   1533111583  026000_A..S

# %%
[(e.vehicle.current_stop_sequence, e.vehicle.trip.route_id) for e in feed.entity if str(e.vehicle)]
# Out:
# [(47, 'A'),
#  (52, 'A'),
#  (38, 'A'),
#  (43, 'A'),
#  (26, 'A'),
#  (31, 'A'),
#  (15, 'A'),
#  (19, 'A'),
#  (5, 'A'),
#  (0, 'A'),
#  (0, 'A'),
#  (0, 'A'),
#  (7, 'A'),
#  (0, 'A'),
#  (0, 'A'),
#  (0, 'A'),
#  (0, 'A'),
#  (0, 'A'),
#  (18, 'E'),
#  (30, 'E'),
#  (13, 'E'),
#  (26, 'E'),
#  (1, 'E'),
#  (0, 'E'),
#  (0, 'E'),
#  (4, 'E'),
#  (0, 'E'),
#  (5, 'H'),
#  (3, 'H'),
#  (0, 'H'),
#  (0, 'H'),
#  (0, 'H'),
#  (3, 'FS'),
#  (0, 'FS'),
#  (0, 'FS'),
#  (0, 'FS'),
#  (0, 'FS')]

# %%
[p.replacement_period.end - feed.header.timestamp for p in feed.header.ListFields()[-1][-1].trip_replacement_period]
# Out:
# [1800, 1786, 1788, 1791, 1792]

# %%
desc = entity.ListFields()[0][0]

# %%
[x[0].name for x in entity.ListFields()]
# Out:
# ['id', 'trip_update']

# %% [markdown]
# ### protobuf to dict

# %%
from protobuf_to_dict import protobuf_to_dict

# %%
protobuf_to_dict(feed)['header']['___X']['1001'][]
# Out:
# {'nyct_subway_version': '1.0',
#  'trip_replacement_period': [{'route_id': 'A',
#    'replacement_period': {'end': 1533113386}},
#   {'route_id': 'C', 'replacement_period': {'end': 1533113372}},
#   {'route_id': 'E', 'replacement_period': {'end': 1533113374}},
#   {'route_id': 'H', 'replacement_period': {'end': 1533113377}},
#   {'route_id': 'FS', 'replacement_period': {'end': 1533113378}}]}

# %% [markdown]
# ### Exploration

# %%
s = shapes[shapes.shape_id == '1..N03R'].copy(deep=True)

# geoplotlib.dot(shapes.rename({'shape_pt_lat':'lat', 'shape_pt_lon':'lon'}, axis=1))
# geoplotlib.show()

# %%
g = pd.DataFrame()
g['src_lat'] = s.shape_pt_lat.shift(1)
g['src_lon'] = s.shape_pt_lon.shift(1)
g['dest_lat'] = s.shape_pt_lat
g['dest_lon'] = s.shape_pt_lon

# %%
gpl.graph(g[1:],'src_lat','src_lon','dest_lat','dest_lon', linewidth=10, color='Blues')

# %%
gpl.show()

# %%
scheds.columns
# Out:
# Index(['A25N', 'A27N', 'A28N', 'A30N', 'A31N', 'A32N', 'A33N', 'A34N', 'D14N',
#        'F06N', 'F09N', 'F11N', 'F12N', 'G05N', 'G06N', 'G07N', 'G08N', 'G14N',
#        'G21N'],
#       dtype='object')

# %%
stops[stops.stop_id.]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-378f101492df> in <module>()
# ----> 1 stops[stops.stop_id in scheds.columns]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    2033     @Appender(_index_shared_docs['__contains__'] % _index_doc_kwargs)
#    2034     def __contains__(self, key):
# -> 2035         hash(key)
#    2036         try:
#    2037             return key in self._engine
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
stops.set_index('stop_id')
# Out:
#                            stop_name   stop_lat   stop_lon  location_type  \
# stop_id
# 101      Van Cortlandt Park - 242 St  40.889248 -73.898583              1
# 101N     Van Cortlandt Park - 242 St  40.889248 -73.898583              0
# 101S     Van Cortlandt Park - 242 St  40.889248 -73.898583              0
# 103                           238 St  40.884667 -73.900870              1
# 103N                          238 St  40.884667 -73.900870              0
# 103S                          238 St  40.884667 -73.900870              0
# 104                           231 St  40.878856 -73.904834              1
# 104N                          231 St  40.878856 -73.904834              0
# 104S                          231 St  40.878856 -73.904834              0
# 106             Marble Hill - 225 St  40.874561 -73.909831              1
# 106N            Marble Hill - 225 St  40.874561 -73.909831              0
# 106S            Marble Hill - 225 St  40.874561 -73.909831              0
# 107                           215 St  40.869444 -73.915279              1
# 107N                          215 St  40.869444 -73.915279              0
# 107S                          215 St  40.869444 -73.915279              0
# 108                           207 St  40.864621 -73.918822              1
# 108N                          207 St  40.864621 -73.918822              0
# 108S                          207 St  40.864621 -73.918822              0
# 109                       Dyckman St  40.860531 -73.925536              1
# 109N                      Dyckman St  40.860531 -73.925536              0
# 109S                      Dyckman St  40.860531 -73.925536              0
# 110                           191 St  40.855225 -73.929412              1
# 110N                          191 St  40.855225 -73.929412              0
# 110S                          191 St  40.855225 -73.929412              0
# 111                           181 St  40.849505 -73.933596              1
# 111N                          181 St  40.849505 -73.933596              0
# 111S                          181 St  40.849505 -73.933596              0
# 112          168 St - Washington Hts  40.840556 -73.940133              1
# 112N         168 St - Washington Hts  40.840556 -73.940133              0
# 112S         168 St - Washington Hts  40.840556 -73.940133              0
# ...                              ...        ...        ...            ...
# S22                         New Dorp  40.573480 -74.117210              1
# S22N                        New Dorp  40.573480 -74.117210              0
# S22S                        New Dorp  40.573480 -74.117210              0
# S23                       Grant City  40.578965 -74.109704              1
# S23N                      Grant City  40.578965 -74.109704              0
# S23S                      Grant City  40.578965 -74.109704              0
# S24                     Jefferson Av  40.583591 -74.103338              1
# S24N                    Jefferson Av  40.583591 -74.103338              0
# S24S                    Jefferson Av  40.583591 -74.103338              0
# S25                     Dongan Hills  40.588849 -74.096090              1
# S25N                    Dongan Hills  40.588849 -74.096090              0
# S25S                    Dongan Hills  40.588849 -74.096090              0
# S26                         Old Town  40.596612 -74.087368              1
# S26N                        Old Town  40.596612 -74.087368              0
# S26S                        Old Town  40.596612 -74.087368              0
# S27                         Grasmere  40.603117 -74.084087              1
# S27N                        Grasmere  40.603117 -74.084087              0
# S27S                        Grasmere  40.603117 -74.084087              0
# S28                          Clifton  40.621319 -74.071402              1
# S28N                         Clifton  40.621319 -74.071402              0
# S28S                         Clifton  40.621319 -74.071402              0
# S29                        Stapleton  40.627915 -74.075162              1
# S29N                       Stapleton  40.627915 -74.075162              0
# S29S                       Stapleton  40.627915 -74.075162              0
# S30                    Tompkinsville  40.636949 -74.074835              1
# S30N                   Tompkinsville  40.636949 -74.074835              0
# S30S                   Tompkinsville  40.636949 -74.074835              0
# S31                        St George  40.643748 -74.073643              1
# S31N                       St George  40.643748 -74.073643              0
# S31S                       St George  40.643748 -74.073643              0
#
#         parent_station
# stop_id
# 101                NaN
# 101N               101
# 101S               101
# 103                NaN
# 103N               103
# 103S               103
# 104                NaN
# 104N               104
# 104S               104
# 106                NaN
# 106N               106
# 106S               106
# 107                NaN
# 107N               107
# 107S               107
# 108                NaN
# 108N               108
# 108S               108
# 109                NaN
# 109N               109
# 109S               109
# 110                NaN
# 110N               110
# 110S               110
# 111                NaN
# 111N               111
# 111S               111
# 112                NaN
# 112N               112
# 112S               112
# ...                ...
# S22                NaN
# S22N               S22
# S22S               S22
# S23                NaN
# S23N               S23
# S23S               S23
# S24                NaN
# S24N               S24
# S24S               S24
# S25                NaN
# S25N               S25
# S25S               S25
# S26                NaN
# S26N               S26
# S26S               S26
# S27                NaN
# S27N               S27
# S27S               S27
# S28                NaN
# S28N               S28
# S28S               S28
# S29                NaN
# S29N               S29
# S29S               S29
# S30                NaN
# S30N               S30
# S30S               S30
# S31                NaN
# S31N               S31
# S31S               S31
#
# [1503 rows x 5 columns]
